# %% [markdown]
# ### Importing essential libraries for EDA

# %%
# !pip3 install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: packaging>=20.0 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: cycler>=0.10 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (6.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.15.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip3 install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.8.0-cp39-cp39-macosx_11_0_arm64.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.1)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.43.1-cp39-cp39-macosx_10_9_universal2.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 251 kB/s eta 0:00:01
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp39-cp39-macosx_11_0_arm64.whl (232 kB)
#      |████████████████████████████████| 232 kB 1.9 MB/s eta 0:00:01
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.1.0-cp39-cp39-macosx_11_0_arm64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 957 kB/s eta 0:00:01
# Requirement already satisfied: numpy<2,>=1.21 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.25.2)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 7.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.1.0-py3-none-any.whl (33 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl (66 kB)
#      |████████████████████████████████| 66 kB 6.1 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in /Users/badavath.srikanth/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 importlib-resources-6.1.0 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.1.0 pyparsing-3.1.1
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading the data

# %%
df = pd.read_csv('Data/insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# The factors that might affect the health insurance cost are:-
# * **Age**: Age of the beneficiary
# * **Sex**: Gender of the beneficiary
# * **BMI**: Body Mass Index (kg / m^2)
# * **Children**: Number of children / Number of dependants
# * **Smoker**: Does smoke or not
# * **Region**: Residential area of the beneficiary

# %% [markdown]
# ### Analysing the data stats

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# The datatype of the all the categories are correct, hence no changes needed. Also, there are no null valued elements

# %%
df['charges'].describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %% [markdown]
# This shows a brief description of the Charges column.<br>
# Few observations:-
# * The minimum cost of an insurance is 1122
# * Around 75% of the charges are below 17,000
# * The maximum cost of an insurance is 63770

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Let's analyze the medical insurance charges by age, bmi and children according to the smoking factor

# %%
sns.lmplot( x='bmi',y='charges', data=df, hue='smoker', palette='Set1', scatter_kws={"s": 10})
plt.show()

# %%
sns.lmplot(x='age', y='charges', hue='smoker', data=df, palette='inferno', scatter_kws={"s": 10})
plt.show()

# %%
sns.lmplot(x='children', y='charges', hue='smoker', data=df, palette='cool', scatter_kws={"s": 10})
plt.show()

# %% [markdown]
# Smoking has the highest impact on the medical insurance costs, even though costs are increasing with age, bmi and children. Also people with children tend to smoke less.

# %%
f, axs = plt.subplots(1,1, figsize=(12,8))
plot_order = df.groupby('region')['charges'].sum().sort_values(ascending=True).index.values
sns.barplot(x='region', y='charges', data=df, palette='Blues', order=plot_order)
plt.show()

# %% [markdown]
# So overall the highest medical insurance charges are in the Southeast and the lowest are in the Southwest. Taking into account certain factors (sex, smoking, having children) let's see how it changes by region

# %%
f, axs = plt.subplots(1,1, figsize=(12,8))
sns.barplot(x='region', y='charges', hue='sex', data=df, palette='BuGn')
plt.show()

# %%
f, axs = plt.subplots(1,1, figsize=(12,8))
sns.barplot(x='region', y='charges', hue='smoker', data=df, palette='BuPu_r')
plt.show()

# %%
f, ax = plt.subplots(1, 1, figsize=(16, 8))
sns.barplot(x='region', y='charges', hue='children', data=df, palette='Reds')
plt.show()

# %% [markdown]
# From the above graphs we can say that the highest charges are still in Southeast. People in Southeast smoke more than people in Northeast, but people in Northeast have higher charges by gender than in Southwest and Northwest overall. And people with children tend to have higher medical costs overall as well.

# %% [markdown]
# ### Modifying the data for prediction

# %% [markdown]
# Converting object labels into categorical

# %%
df[['sex', 'smoker', 'region']] = df[['sex', 'smoker', 'region']].astype('category')
df.dtypes
# Out:
# age            int64
# sex         category
# bmi          float64
# children       int64
# smoker      category
# region      category
# charges      float64
# dtype: object

# %% [markdown]
# Converting category labels into numerical using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit(df.sex.drop_duplicates())
df.sex = le.transform(df.sex)

le.fit(df.smoker.drop_duplicates())
df.smoker = le.transform(df.smoker)

le.fit(df.region.drop_duplicates())
df.region = le.transform(df.region)

df.dtypes
# Out:
# age           int64
# sex           int64
# bmi         float64
# children      int64
# smoker        int64
# region        int64
# charges     float64
# dtype: object

# %%
f, axs = plt.subplots(1,1, figsize=(12,12))
sns.heatmap(df.corr(), annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# No correlation, except with smoking

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['region'].unique()
# Out:
# array([3, 2, 1, 0])

# %% [markdown]
# Region 0 -> Northeast <br>
# Region 1 -> Northwest <br>
# Region 2 -> Southeast <br>
# Region 3 -> Southwest

# %% [markdown]
# ### Multiple Linear Regression
# This is commonly used in predictive analysis. This regression estimates are used to explain the relationship between one dependent variable and one or more independent variables

# %%
X = np.array(df.iloc[:,:-1]) # Independent variables
y = np.array(df.iloc[:,-1])   # Dependent variable

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)

# %%
X.shape, y.shape
# Out:
# ((1338, 6), (1338,))

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1003, 6), (335, 6), (1003, 1), (335, 1))

# %%
# Training the model
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = reg.predict(X_test)

# %%
accuracy = reg.score(X_test, y_test)
print('Accuracy = ', accuracy)
# Out:
# Accuracy =  0.7962732059725787

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge
r = Ridge(alpha=0.5)
r.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5)

# %%
ridge_accuracy = r.score(X_test, y_test)
print('Accuracy = ', ridge_accuracy)
# Out:
# Accuracy =  0.7961319557404142

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor as rfr
rf_reg = rfr(n_estimators = 10,random_state = 0)

rf_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1003, 6), (335, 6), (1003, 1), (335, 1))

# %%
accuracy = rf_reg.score(X_test, y_test)
print(f'Accuracy : {accuracy:.3}')
# Out:
# Accuracy : 0.86

# %% [markdown]
# ### Saving the model

# %%
import pickle
fname = 'Model/model.pkl'
pickle.dump(rf_reg, open(fname, 'wb'))

# %% [markdown]
# ### Conclusion

# %% [markdown]
# * **Smoking** is the greatest factor that affects medical cost charges, then it's **bmi** and **age**.
# * **Random Forest Regression** turned out to be the best model
